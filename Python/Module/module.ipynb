# %% [markdown]
# # Module

# %% [markdown]
# A module is just a Python file (.py) that contains functions, variables, or classes.
#
# 👉 It helps us reuse code.
#
# 📌 Simple Meaning:
#
# One .py file = One module

# %% [markdown]
# ## 🔹 Example of Module

# %% [markdown]
# ### Step 1: Create a file named mymath.py

# %%
# mymath.py

def add(a, b):
    return a + b

def multiply(a, b):
    return a * b

# %% [markdown]
# ### Step 2: Use this module in another file

# %%
#import mymath

#print(mymath.add(5, 3))
#print(mymath.multiply(4, 2))

# %% [markdown]
# # Packages

# %% [markdown]
# A package is a folder that contains multiple modules.
#
# 👉 It helps organize large projects.
#
# 📌 Simple Meaning:
#
# Folder + Multiple .py files = Package

# %% [markdown]
# ### 🔹 Example of Package Structure

# %% [markdown]
# mypackage/
# │
#
# ├── __init__.py
#
# ├── math1.py
#
# └── math2.py

# %% [markdown]
# math1.py

# %%
def add(a, b):
    return a + b

# %% [markdown]
# math2.py

# %%
def subtract(a, b):
    return a - b

# %% [markdown]
# ### Using the Package

# %%
#from mypackage import math1

#print(math1.add(5, 2))

# %% [markdown]
# ### Built-in Module Example

# %%
import math

print(math.sqrt(16))
# Out:
# 4.0

# %% [markdown]
# Here:
#
#
# math = built-in module
#
#
# sqrt() = function inside module
