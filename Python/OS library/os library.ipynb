# %% [markdown]
# # OS Library

# %% [markdown]
# os module helps us interact with the Operating System
# We can work with:
#
# Files
#
# Folders
#
# Paths
#
# Environment variables
#
# System information

# %% [markdown]
# ## How to Import

# %%
#import os

# %% [markdown]
# ### 1️⃣ Get Current Working Directory

# %%
import os

print(os.getcwd())

# %% [markdown]
# ### 2️⃣ Change Directory

# %%
os.chdir("C:/Users")

# %% [markdown]
# ### 3️⃣ List Files in a Folder

# %%
print(os.listdir())

# %% [markdown]
# ### 4️⃣ Create a Folder

# %%
os.mkdir("NewFolder")

# %% [markdown]
# ### 5️⃣ Remove a Folder

# %%
os.rmdir("NewFolder")

# %% [markdown]
# ### 6️⃣ Remove a File

# %%
os.remove("example.txt")

# %% [markdown]
# ### 7️⃣ Check if File Exists

# %%
if os.path.exists("example.txt"):
    print("File exists")
else:
    print("File not found")

# %% [markdown]
# ### 8️⃣ Get File Size

# %%
size = os.path.getsize("example.txt")
print("File size:", size, "bytes")

# %% [markdown]
# ### 9️⃣ Rename a File

# %%
os.rename("old.txt", "new.txt")

# %% [markdown]
# ### 🔟 Get OS Name

# %%
print(os.name)

# %% [markdown]
# Output:
#
# "nt" → Windows
#
# "posix" → Linux / Mac
