# %% [markdown]
# # IMPORTANT LIBRARIES

# %% [markdown]
# ## 1️⃣ math (Mathematical operations)
#
#  Used for mathematical calculations.

# %%
import math

print(math.sqrt(25))     # Square root
print(math.factorial(5)) # Factorial
print(math.pi)           # Value of pi
# Out:
# 5.0
# 120
# 3.141592653589793

# %% [markdown]
# ## 2️⃣ random (Random numbers)
#
#  Used to generate random numbers.

# %%
import random

print(random.randint(1, 10))   # Random number between 1 and 10
print(random.choice(["apple", "banana", "mango"]))  # Random choice
# Out:
# 4
# apple

# %% [markdown]
# ## 3️⃣ datetime (Date and Time)
#
#  Used to work with date and time.

# %%
import datetime

now = datetime.datetime.now()
print(now)
# Out:
# 2026-02-14 23:44:59.666642

# %% [markdown]
# ## 4️⃣ os (Operating system)
#
# 👉 Used to interact with system files and folders.

# %%
import os

print(os.getcwd())   # Current folder
print(os.listdir())  # List files
# Out:
# c:\Users\fansc\OneDrive\Desktop\genAI\Python\libraries
# ['imp_lib.ipynb']

# %% [markdown]
# ## 5️⃣ sys (System functions)
#
# 👉 Used to interact with Python runtime.

# %%
import sys

print(sys.version)   # Python version
# Out:
# 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# ## 6️⃣ numpy (Numerical computing)
#
# 👉 Used for working with arrays and numbers (Data Science).

# %%
# import numpy as np

# arr = np.array([1, 2, 3, 4])
# print(arr * 2)

# %% [markdown]
# ## 7️⃣ pandas (Data handling)
#
# 👉 Used for working with tables (Excel-like data).

# %%
# import pandas as pd

data = {"Name": ["A", "B"], "Age": [20, 25]}
# df = pd.DataFrame(data)

# print(df)

# %% [markdown]
# ## 8️⃣ matplotlib (Data visualization)
#
# 👉 Used to draw graphs and charts

# %%
# import matplotlib.pyplot as plt

# plt.plot([1,2,3], [4,5,6])
# plt.show()

# %% [markdown]
# ### Types of Libraries

# %% [markdown]
# | Type     | Example                   |
# | -------- | ------------------------- |
# | Built-in | math, os, sys             |
# | External | numpy, pandas, matplotlib |

# %% [markdown]
# ### Simple Summary

# %% [markdown]
# math → Calculations
#
# random → Random numbers
#
# datetime → Date & time
#
# os → System work
#
# numpy → Arrays
#
# pandas → Data tables
#
# matplotlib → Graphs
