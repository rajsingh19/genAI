# %% [markdown]
# # Streamlit

# %% [markdown]
# 👉 Streamlit is a Python library used to build web apps for data science and machine learning easily.
#
# 👉 You can create a web application using only Python (no HTML, CSS, JS needed).
#
#    It is Open - Source library

# %% [markdown]
# ### ✅ Why Do We Use Streamlit?
#
# Normally to build a website, we need:
#
# HTML
#
# CSS
#
# JavaScript
#
# Backend framework
#
# But with Streamlit:
#
# 👉 Just write Python code
#
# 👉 It automatically creates a web app
#
# It is mainly used for:
#
# Data visualization
#
# Machine learning model demo
#
# Dashboards
#
# Data analysis apps
#
# Interactive tools

# %% [markdown]
# ### How to Install Streamlit

# %%
# pip install streamlit

# %% [markdown]
# ### How to Run Streamlit App

# %%
# streamlit run app.py

# %% [markdown]
# ### Basic Structure of Streamlit App
#
# Create file: app.py

# %%
#import streamlit as st

#st.title("My First Streamlit App")
#st.write("Hello World!")

# %% [markdown]
# ### Important Streamlit Operations

# %%
# st.title("Main Title")
# st.header("Header")
# st.subheader("Subheader")
# st.text("Simple text")
# st.write("Any data type")

# %% [markdown]
# ### 2️⃣ User Input Widgets
#
# Streamlit allows interactive input.
#
# Text Input

# %%
# name = st.text_input("Enter your name")
# st.write("Hello", name)

# %% [markdown]
# ### Number Input

# %%
# num = st.number_input("Enter a number")
# st.write("You entered:", num)

# %% [markdown]
# ### Button

# %%
# if st.button("Click Me"):
#    st.write("Button Clicked!")

# %% [markdown]
# ### Slider

# %%
# age = st.slider("Select age", 1, 100)
# st.write("Age:", age)

# %% [markdown]
# ### 3️⃣ Display Data

# %%
'''
import pandas as pd

data = pd.DataFrame({
    "Name": ["A", "B"],
    "Age": [20, 25]
})

st.dataframe(data)
'''
# Out:
# '\nimport pandas as pd\n\ndata = pd.DataFrame({\n    "Name": ["A", "B"],\n    "Age": [20, 25]\n})\n\nst.dataframe(data)\n'

# %% [markdown]
# ### 4️⃣ Display Charts

# %%
'''
import pandas as pd
import numpy as np

data = pd.DataFrame(
    np.random.randn(20, 3),
    columns=["A", "B", "C"]
)

st.line_chart(data)
'''
# Out:
# '\nimport pandas as pd\nimport numpy as np\n\ndata = pd.DataFrame(\n    np.random.randn(20, 3),\n    columns=["A", "B", "C"]\n)\n\nst.line_chart(data)\n'

# %% [markdown]
# ### 5️⃣ File Upload

# %%
# file = st.file_uploader("Upload a file")

# if file is not None:
#     st.write(file.name)

# %% [markdown]
# ### 6️⃣ Sidebar

# %%
# st.sidebar.title("Sidebar Menu")
# option = st.sidebar.selectbox("Choose", ["Home", "About"])
